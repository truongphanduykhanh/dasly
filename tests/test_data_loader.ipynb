# %%
from dasly.data_loader import DataLoader

# %% [markdown]
# # Load data with a folder path

# %%
das = DataLoader()
das.load_data(
    folder_path='/media/kptruong/yellow02/Aastfjordbrua/',
    start='20230901 103015',
    duration=60
)
# Out:
# 7 files, from 103014 to 103114

# %%
das.file_paths
# Out:
# ['/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103014.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103024.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103034.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103044.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103054.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103104.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103114.hdf5']

# %%
das.signal
# Out:
#                           0             1         2             3         4    \
# 10:30:15         6.497454e-06  4.632444e-06 -0.000015 -1.319545e-05  0.000003
# 10:30:15.001000 -1.437862e-05 -7.179285e-06  0.000014 -9.425319e-07 -0.000010
# 10:30:15.002000  8.382517e-06  4.973360e-06 -0.000007 -2.466626e-06  0.000004
# 10:30:15.003000 -8.001494e-06  4.191259e-06  0.000024  1.361658e-05 -0.000004
# 10:30:15.004000  7.981440e-06  5.434599e-06 -0.000009 -1.365669e-05  0.000005
# ...                       ...           ...       ...           ...       ...
# 10:31:14.995000  1.844956e-05  6.798262e-06 -0.000020 -3.369050e-06  0.000004
# 10:31:14.996000 -3.409158e-07  2.205926e-06  0.000004 -3.108350e-06  0.000001
# 10:31:14.997000 -7.239447e-06 -8.823703e-07  0.000011 -3.008080e-07 -0.000012
# 10:31:14.998000  1.323555e-06  7.018854e-07 -0.000007 -4.552228e-06  0.000005
# 10:31:14.999000 -7.580363e-06 -1.457916e-05 -0.000004  1.251361e-05  0.000008
#
# ...

# %%
# data shape
das.signal.shape
# Out:
# (60000, 800)

# %%
# time start
das.start
# Out:
# Timestamp('2023-09-01 10:30:15')

# %%
# time end
das.end
# Out:
# Timestamp('2023-09-01 10:31:14.999000')

# %%
# temporal sampling rate
das.t_rate
# Out:
# 1000.0

# %%
# spatial sampling rate
das.s_rate
# Out:
# 1.0

# %%
# duration
das.duration
# Out:
# 60.0

# %%
# distance between two consecutive channels
das.ch_space
# Out:
# 1

# %% [markdown]
# # Load data with a file path

# %%
das = DataLoader()
das.load_data('/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103014.hdf5')

# %%
das.file_paths
# Out:
# '/media/kptruong/yellow02/Aastfjordbrua/20230901/dphi/103014.hdf5'

# %%
das.signal
# Out:
#                       0             1         2         3             4    \
# 10:30:14.488000 -0.000003 -8.222087e-07  0.000008  0.000007 -2.506734e-06
# 10:30:14.489000 -0.000006 -4.652498e-06  0.000003  0.000001  6.216700e-07
# 10:30:14.490000  0.000007  4.873090e-06 -0.000009 -0.000018  7.018854e-07
# 10:30:14.491000 -0.000007 -8.462733e-06 -0.000002  0.000010  4.772821e-06
# 10:30:14.492000 -0.000006 -7.279555e-06 -0.000001  0.000010  3.168512e-06
# ...                   ...           ...       ...       ...           ...
# 10:30:24.483000  0.000002 -2.807542e-06 -0.000013 -0.000014  6.597723e-06
# 10:30:24.484000 -0.000010 -3.188565e-06  0.000017  0.000013 -6.176592e-06
# 10:30:24.485000  0.000009  7.700686e-06 -0.000010 -0.000018 -3.409158e-07
# 10:30:24.486000  0.000004  6.076323e-06  0.000005  0.000002 -1.203232e-07
# 10:30:24.487000 -0.000009 -2.667165e-06  0.000009  0.000008 -1.544148e-06
#
#                           5             6             7             8    \
# ...

# %%
# data shape
das.signal.shape
# Out:
# (10000, 800)

# %%
# time start
das.start
# Out:
# Timestamp('2023-09-01 10:30:14.488000')

# %%
# time end
das.end
# Out:
# Timestamp('2023-09-01 10:30:24.487000')

# %%
# temporal sampling rate
das.t_rate
# Out:
# 1000.0

# %%
# spatial sampling rate
das.s_rate
# Out:
# 1.0

# %%
# duration
das.duration
# Out:
# 10.0

# %%
# distance between two consecutive channels
das.ch_space
# Out:
# 1

# %% [markdown]
# # Load data with a folder path not start at exact second

# %%
das = DataLoader()
das.load_data(
    folder_path='/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/',
    start='20230724 175906',
    duration=60
)
# Out:
# 6 files, from 175906 to 175956

# %%
das.file_paths
# Out:
# ['/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175906.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175916.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175926.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175936.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175946.hdf5',
#  '/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175956.hdf5']

# %%
das.signal
# Out:
#                           0             1         2             3    \
# 17:59:06.922000  1.614337e-05  2.947919e-06 -0.000016  2.145764e-06
# 17:59:06.923000 -8.603110e-06  7.419932e-07  0.000009  5.173898e-06
# 17:59:06.924000 -1.877042e-05 -9.204726e-06  0.000017  3.489373e-06
# 17:59:06.925000  1.712601e-05  7.760847e-06 -0.000016 -1.092936e-05
# 17:59:06.926000 -3.429212e-06  2.667165e-06  0.000008 -9.826396e-07
# ...                       ...           ...       ...           ...
# 18:00:05.995000 -1.349625e-05 -9.264888e-06  0.000000  1.397755e-05
# 18:00:05.996000 -2.276114e-05 -1.538132e-05  0.000034  1.546153e-05
# 18:00:05.997000  4.287517e-05  1.698563e-05 -0.000050 -1.860999e-05
# 18:00:05.998000 -7.419932e-07  3.730020e-06  0.000008 -3.890451e-06
# 18:00:05.999000 -1.022747e-05 -1.504040e-06  0.000008 -2.867703e-06
#
#                           4             5             6             7    \
# 17:59:06.922000  1.584256e-06 -3.108350e-06 -1.403771e-07  6.617777e-07
# ...

# %%
# data shape
das.signal.shape
# Out:
# (59078, 800)

# %%
# time start
das.start
# Out:
# Timestamp('2023-07-24 17:59:06.922000')

# %%
# time end
das.end
# Out:
# Timestamp('2023-07-24 18:00:05.999000')

# %%
# temporal sampling rate
das.t_rate
# Out:
# 1000.0

# %%
# spatial sampling rate
das.s_rate
# Out:
# 1.0

# %%
# duration
das.duration
# Out:
# 59.078

# %%
# distance between two consecutive channels
das.ch_space
# Out:
# 1
