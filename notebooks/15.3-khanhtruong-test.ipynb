# %%
from typing import Union
from datetime import datetime, timedelta

import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns; sns.set()
import cv2
from sklearn.cluster import DBSCAN
import math
from datetime import timedelta
from scipy.ndimage import convolve
from tqdm import tqdm

from src import dasly, helper

# %%
das = dasly.Dasly()
das.load_data(
    folder_path='/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/',
    # folder_path='/media/kptruong/yellow02/Aastfjordbrua/',
    start='20231005 083305',
    # start='20231005 094345',
    # start='20231005 082445',
    # start='20231005 082445',
    # start='20230901 103015',  # full 2 lines
    # start='20230901 163110',  # part of lines
    # start='20230901 183015',  # noise
    # start='20230901 104015',  # 2 lines close to each other
    duration=60
)
# Out:
# Welcome to Dasly!
# 7 files, from 083304 to 083404

# %%
das.heatmap()
# Out:
# vmin: -6.66e-06, vmax: 6.66e-06
