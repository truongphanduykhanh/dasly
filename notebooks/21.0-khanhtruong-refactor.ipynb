# %%
from dasly import data_loader

# %%
from dasly import dasly_new

# %%
das = dasly_new.Dasly()
file_path = '/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/20230724/dphi/175906.hdf5'
das.load_data(file_paths=file_path)
das.signal.head()
# Out:
#                       0             1         2             3             4    \
# 17:59:06.922000  0.000016  2.947919e-06 -0.000016  2.145764e-06  1.584256e-06
# 17:59:06.923000 -0.000009  7.419932e-07  0.000009  5.173898e-06  1.403771e-07
# 17:59:06.924000 -0.000019 -9.204726e-06  0.000017  3.489373e-06 -3.709966e-06
# 17:59:06.925000  0.000017  7.760847e-06 -0.000016 -1.092936e-05  2.045495e-06
# 17:59:06.926000 -0.000003  2.667165e-06  0.000008 -9.826396e-07 -4.251420e-06
#
#                       5             6             7         8             9    \
# 17:59:06.922000 -0.000003 -1.403771e-07  6.617777e-07 -0.000002 -3.048188e-06
# 17:59:06.923000 -0.000004  8.222087e-07 -2.526788e-06  0.000001  3.228673e-06
# 17:59:06.924000  0.000002  3.830289e-06  4.211312e-06 -0.000001 -2.988027e-06
# 17:59:06.925000  0.000003 -7.279555e-06 -3.048188e-06  0.000002  2.807542e-07
# 17:59:06.926000 -0.000002  2.045495e-06  3.088296e-06 -0.000001 -2.005387e-06
#
#                  ...       790           791       792           793  \
# 17:59:06.922000  ... -0.000001  6.617777e-07  0.000002  4.111043e-06
# 17:59:06.923000  ... -0.000004 -4.472013e-06 -0.000004 -1.030769e-05
# 17:59:06.924000  ...  0.000006  3.950612e-06  0.000004  9.044295e-06
# 17:59:06.925000  ... -0.000005 -6.818316e-06 -0.000003 -3.409158e-07
# 17:59:06.926000  ...  0.000006  2.687219e-06 -0.000003 -2.426518e-06
#
#                           794           795       796           797  \
# 17:59:06.922000  8.021548e-08 -4.732713e-06 -0.000003 -4.993414e-06
# 17:59:06.923000 -9.084403e-06  7.821009e-07  0.000004  7.640524e-06
# 17:59:06.924000  9.365157e-06  3.208619e-07 -0.000005 -6.196646e-06
# 17:59:06.925000 -3.750074e-06 -2.566895e-06  0.000001  2.486680e-06
# 17:59:06.926000  4.552228e-06  5.173898e-06  0.000002  2.005387e-07
#
#                           798       799
# 17:59:06.922000  8.623164e-07  0.000003
# 17:59:06.923000 -4.211313e-07 -0.000007
# 17:59:06.924000  3.369050e-06  0.000010
# 17:59:06.925000 -4.211312e-06 -0.000009
# 17:59:06.926000  4.772821e-06  0.000007
#
# [5 rows x 800 columns]

# %%
das.bandpass_filter(3, 10)
das.signal.head()
# Out:
#                           0             1             2             3    \
# 17:59:06.922000  3.567027e-12  6.513702e-13 -3.513854e-12  4.741266e-13
# 17:59:06.923000  2.620868e-11  5.297010e-12 -2.566115e-11  4.879530e-12
# 17:59:06.924000  9.118730e-11  1.940259e-11 -8.882266e-11  2.444303e-11
# 17:59:06.925000  2.088155e-10  4.490175e-11 -2.025400e-10  7.842765e-11
# 17:59:06.926000  3.731222e-10  7.993635e-11 -3.596562e-10  1.834095e-10
# 17:59:06.922000 -3.469319e-06 -4.993414e-06  8.623164e-07  3.068242e-06
# 17:59:06.923000  3.750074e-06  7.640524e-06 -4.211313e-07 -7.339716e-06
# 17:59:06.924000 -5.073629e-06 -6.196646e-06  3.369050e-06  9.565696e-06
# 17:59:06.925000  1.283448e-06  2.486680e-06 -4.211312e-06 -8.743487e-06
# 17:59:06.926000  1.624363e-06  2.005387e-07  4.772821e-06  6.798262e-06
# ...                       ...           ...           ...           ...
# 17:59:16.917000 -3.228673e-06 -2.165818e-06 -9.024241e-07 -2.205926e-07
# 17:59:16.918000 -3.990720e-06 -1.885064e-06  1.744687e-06 -8.021548e-08
# 17:59:16.919000  2.065549e-06  2.366357e-06  1.363663e-06  1.844956e-06
# 17:59:16.920000  3.730020e-06  1.604310e-06 -1.223286e-06 -6.016161e-08
# 17:59:16.921000  7.821009e-07 -1.544148e-06 -9.826396e-07 -1.383717e-06
#
# [10000 rows x 800 columns]

# %%
aaa.load_data(
    folder_path='/media/kptruong/yellow02/Aastfjordbrua/Aastfjordbrua/',
    # folder_path='/media/kptruong/yellow02/Aastfjordbrua/',
    # start='20231005 094335',
    # start='20231005 082445',
    # start='20231005 082445',
    # start='20230901 103035',  # full 2 lines
    # start='20230901 163110',  # part of lines
    # start='20230901 183015',  # noise
    # start='20230901 104035',  # 2 lines close to each other
    start='20230724 175906',  # 2 lines close to each other
    duration=15
)
# Out:
# 2 files, from 175906 to 175916

# %%
import h5py

# Define the path to your HDF5 file
hdf5_file_path = file_path

# Open the HDF5 file and list all datasets
with h5py.File(hdf5_file_path, 'r') as hdf:
    def print_structure(name, obj):
        if isinstance(obj, h5py.Dataset):
            print(f"Dataset: {name} | Shape: {obj.shape} | Data type: {obj.dtype}")
        elif isinstance(obj, h5py.Group):
            print(f"Group: {name}")
    hdf.visititems(print_structure)
# Out:
# Group: acqSpec
# Dataset: acqSpec/YvsXDelay | Shape: () | Data type: int32
# Dataset: acqSpec/adcDec | Shape: () | Data type: int32
# Dataset: acqSpec/dacGainXi | Shape: () | Data type: int32
# Dataset: acqSpec/dacGainXq | Shape: () | Data type: int32
# Dataset: acqSpec/dacGainYi | Shape: () | Data type: int32
# Dataset: acqSpec/dacGainYq | Shape: () | Data type: int32
# Dataset: acqSpec/dacMixerGain | Shape: () | Data type: int32
# Dataset: acqSpec/dacPhaseBalanceX | Shape: () | Data type: int32
# Dataset: acqSpec/dacPhaseBalanceY | Shape: () | Data type: int32
# Dataset: acqSpec/externalClock | Shape: () | Data type: int32
# Dataset: acqSpec/frequencyOffset | Shape: () | Data type: float64
# Dataset: acqSpec/inputMode | Shape: () | Data type: int32
# Dataset: acqSpec/interpolation | Shape: () | Data type: int32
# Dataset: acqSpec/nSkipInstr | Shape: () | Data type: int32
# Dataset: acqSpec/nSkipLead | Shape: () | Data type: int32
# Dataset: acqSpec/polarizationModulator | Shape: () | Data type: int32
# Dataset: acqSpec/ppsSyncDelay | Shape: () | Data type: int32
# Dataset: acqSpec/rate | Shape: () | Data type: float64
# Dataset: acqSpec/shutterPulseVsSweepDelay | Shape: () | Data type: int32
# Dataset: acqSpec/switchPos | Shape: () | Data type: int32
# Dataset: acqSpec/trigMode | Shape: () | Data type: int32
# Group: cableSpec
# Dataset: cableSpec/fiberOverLength | Shape: () | Data type: float64
# Dataset: cableSpec/refractiveIndex | Shape: () | Data type: float64
# Dataset: cableSpec/sensorDistances | Shape: (800,) | Data type: float64
# Dataset: cableSpec/zeta | Shape: () | Data type: float64
# Dataset: data | Shape: (10000, 800) | Data type: int16
# Group: demodSpec
# Dataset: demodSpec/aPredTau | Shape: () | Data type: uint8
# Dataset: demodSpec/dTau | Shape: () | Data type: float64
# Dataset: demodSpec/fftShift | Shape: () | Data type: uint32
# Dataset: demodSpec/ifftShift | Shape: () | Data type: uint32
# Dataset: demodSpec/mixerCoeffX1 | Shape: (3,) | Data type: complex128
# Dataset: demodSpec/mixerCoeffX2 | Shape: (3,) | Data type: complex128
# Dataset: demodSpec/mixerCoeffY1 | Shape: (3,) | Data type: complex128
# Dataset: demodSpec/mixerCoeffY2 | Shape: (3,) | Data type: complex128
# Dataset: demodSpec/mixerDelayX | Shape: () | Data type: int32
# Dataset: demodSpec/mixerDelayY | Shape: () | Data type: int32
# Dataset: demodSpec/mixerDisable | Shape: () | Data type: int32
# Dataset: demodSpec/nAvgTau | Shape: () | Data type: uint8
# Dataset: demodSpec/nDiffTau | Shape: () | Data type: uint8
# Dataset: demodSpec/nSkip | Shape: () | Data type: int32
# Dataset: demodSpec/roiDec | Shape: (1,) | Data type: uint32
# Dataset: demodSpec/roiEnd | Shape: (1,) | Data type: uint32
# Dataset: demodSpec/roiStart | Shape: (1,) | Data type: uint32
# Dataset: fileGenerator | Shape: () | Data type: object
# Dataset: fileGeneratorSvnRev | Shape: () | Data type: uint32
# Dataset: fileVersion | Shape: () | Data type: int32
# Group: header
# Dataset: header/channels | Shape: (800,) | Data type: int32
# Dataset: header/computer | Shape: () | Data type: object
# Dataset: header/dataScale | Shape: () | Data type: float64
# Dataset: header/dataType | Shape: () | Data type: int32
# Dataset: header/dimensionNames | Shape: (2,) | Data type: object
# Group: header/dimensionRanges
# Group: header/dimensionRanges/dimension0
# Dataset: header/dimensionRanges/dimension0/max | Shape: () | Data type: int64
# Dataset: header/dimensionRanges/dimension0/min | Shape: () | Data type: int64
# Dataset: header/dimensionRanges/dimension0/size | Shape: () | Data type: int64
# Dataset: header/dimensionRanges/dimension0/unitScale | Shape: () | Data type: float64
# Group: header/dimensionRanges/dimension1
# Dataset: header/dimensionRanges/dimension1/max | Shape: (1,) | Data type: int64
# Dataset: header/dimensionRanges/dimension1/min | Shape: (1,) | Data type: int64
# Dataset: header/dimensionRanges/dimension1/size | Shape: (1,) | Data type: int64
# Dataset: header/dimensionRanges/dimension1/unitScale | Shape: (1,) | Data type: float64
# Dataset: header/dimensionSizes | Shape: (2,) | Data type: int64
# Dataset: header/dimensionUnits | Shape: (2,) | Data type: object
# Dataset: header/dt | Shape: () | Data type: float64
# Dataset: header/dx | Shape: () | Data type: float64
# Dataset: header/experiment | Shape: () | Data type: object
# Dataset: header/gaugeLength | Shape: () | Data type: float64
# Dataset: header/instrument | Shape: () | Data type: object
# Dataset: header/missingSamples | Shape: (0,) | Data type: float64
# Dataset: header/name | Shape: () | Data type: object
# Dataset: header/numberOfAuxData | Shape: () | Data type: int32
# Dataset: header/phiOffs | Shape: (800,) | Data type: float64
# Dataset: header/phiOffsStartTime | Shape: () | Data type: int32
# Dataset: header/sensitivities | Shape: (1, 1) | Data type: float64
# Dataset: header/sensitivityUnits | Shape: (1,) | Data type: object
# Dataset: header/sensorType | Shape: (1,) | Data type: object
# Dataset: header/spatialUnwrRange | Shape: () | Data type: float32
# Dataset: header/time | Shape: () | Data type: float64
# Dataset: header/unit | Shape: () | Data type: object
# Group: instrumentOptions
# Dataset: instrumentOptions/names | Shape: (7,) | Data type: object
# Dataset: instrumentOptions/values | Shape: (7,) | Data type: object
# Group: monitoring
# Group: monitoring/Acq
# Dataset: monitoring/Acq/acquistionRunning | Shape: () | Data type: int32
# Dataset: monitoring/Acq/maxXI | Shape: () | Data type: float64
# Dataset: monitoring/Acq/maxXQ | Shape: () | Data type: float64
# Dataset: monitoring/Acq/maxYI | Shape: () | Data type: float64
# Dataset: monitoring/Acq/maxYQ | Shape: () | Data type: float64
# Dataset: monitoring/Acq/minXI | Shape: () | Data type: float64
# Dataset: monitoring/Acq/minXQ | Shape: () | Data type: float64
# Dataset: monitoring/Acq/minYI | Shape: () | Data type: float64
# Dataset: monitoring/Acq/minYQ | Shape: () | Data type: float64
# Dataset: monitoring/Acq/rmsXI | Shape: () | Data type: float64
# Dataset: monitoring/Acq/rmsXQ | Shape: () | Data type: float64
# Dataset: monitoring/Acq/rmsYI | Shape: () | Data type: float64
# Dataset: monitoring/Acq/rmsYQ | Shape: () | Data type: float64
# Dataset: monitoring/Acq/tempDac | Shape: () | Data type: float64
# Dataset: monitoring/Acq/tempFpga | Shape: () | Data type: float64
# Group: monitoring/Ctrl
# Dataset: monitoring/Ctrl/aLbVoaDB | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/aLoVoaDB | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/aTxVoaDB | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/cPilotLaser | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/cPilotLaserCtrl | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/controllerFan | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/laserPower | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/loopback | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/pDcMonXIh | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonXIl | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonXQh | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonXQl | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonYIh | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonYIl | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonYQh | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pDcMonYQl | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pPilotLaserCtrlmW | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pTxAvg | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/pTxPeak | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/power | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/powerStatus | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/ppsIn | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/ppsTermination | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/receiverGain | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/sMainFan | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/sPsuFan | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/state | Shape: () | Data type: uint32
# Dataset: monitoring/Ctrl/status | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/statusTxt | Shape: () | Data type: object
# Dataset: monitoring/Ctrl/tController | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tFpga | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tFpgaDac | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tIn | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tLaser | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tOut | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tPsu | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/tenMHzIn | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/trigOut | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/trigTermination | Shape: () | Data type: int32
# Dataset: monitoring/Ctrl/vLbVoa | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/vLoVoa | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/vPilotLaserTemp | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/vPolModA | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/vPolModB | Shape: () | Data type: float64
# Dataset: monitoring/Ctrl/vTxVoa | Shape: () | Data type: float64
# Group: monitoring/Edfa
# Dataset: monitoring/Edfa/current1 | Shape: () | Data type: int32
# Dataset: monitoring/Edfa/gain | Shape: () | Data type: float64
# Dataset: monitoring/Edfa/inputPwr | Shape: () | Data type: float64
# Dataset: monitoring/Edfa/outputPwr | Shape: () | Data type: float64
# Dataset: monitoring/Edfa/pumpMode | Shape: () | Data type: int32
# Dataset: monitoring/Edfa/state | Shape: () | Data type: int32
# Group: monitoring/Gps
# Dataset: monitoring/Gps/gpsPosE | Shape: () | Data type: float64
# Dataset: monitoring/Gps/gpsPosH | Shape: () | Data type: float64
# Dataset: monitoring/Gps/gpsPosN | Shape: () | Data type: float64
# Dataset: monitoring/Gps/gpsStatus | Shape: () | Data type: uint32
# Group: monitoring/Laser
# Dataset: monitoring/Laser/DAIStatus | Shape: () | Data type: uint32
# Dataset: monitoring/Laser/PIDRef | Shape: () | Data type: int32
# Dataset: monitoring/Laser/SOAOn | Shape: () | Data type: int32
# Dataset: monitoring/Laser/SOARef | Shape: () | Data type: int32
# Dataset: monitoring/Laser/agcFmRef | Shape: () | Data type: int32
# Dataset: monitoring/Laser/attenuation | Shape: () | Data type: int32
# Dataset: monitoring/Laser/attenuationDb | Shape: () | Data type: float64
# Dataset: monitoring/Laser/autoZero | Shape: () | Data type: int32
# Dataset: monitoring/Laser/calIntensRef | Shape: () | Data type: int32
# Dataset: monitoring/Laser/extiRnRef | Shape: () | Data type: int32
# Dataset: monitoring/Laser/fNoiseRedOn | Shape: () | Data type: int32
# Dataset: monitoring/Laser/fNoiseRedSetOn | Shape: () | Data type: int32
# Dataset: monitoring/Laser/fanControl | Shape: () | Data type: int32
# Dataset: monitoring/Laser/heatSinkTemp | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iInterf | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iLaser0 | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iLaser1 | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iLim1 | Shape: () | Data type: int32
# Dataset: monitoring/Laser/iOven | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iPeltier0 | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iPeltier1 | Shape: () | Data type: float64
# Dataset: monitoring/Laser/iRef | Shape: () | Data type: int32
# Dataset: monitoring/Laser/ifController | Shape: () | Data type: int32
# Dataset: monitoring/Laser/ifLoop | Shape: () | Data type: int32
# Dataset: monitoring/Laser/interfIStab | Shape: () | Data type: float64
# Dataset: monitoring/Laser/interfTStab | Shape: () | Data type: float64
# Dataset: monitoring/Laser/itu | Shape: () | Data type: int32
# Dataset: monitoring/Laser/ituFrequency | Shape: () | Data type: int32
# Dataset: monitoring/Laser/laserOn | Shape: () | Data type: int32
# Dataset: monitoring/Laser/laserState | Shape: () | Data type: int32
# Dataset: monitoring/Laser/laserTemp | Shape: () | Data type: float64
# Dataset: monitoring/Laser/laserTempFT | Shape: () | Data type: int32
# Dataset: monitoring/Laser/ovenDev | Shape: () | Data type: float64
# Dataset: monitoring/Laser/ovenGain | Shape: () | Data type: int32
# Dataset: monitoring/Laser/ovenSetpoint | Shape: () | Data type: int32
# Dataset: monitoring/Laser/startTime | Shape: () | Data type: int64
# Dataset: monitoring/Laser/status | Shape: () | Data type: uint32
# Dataset: monitoring/Laser/tempAlarm | Shape: () | Data type: int32
# Dataset: monitoring/Laser/updateTime | Shape: () | Data type: int64
# Dataset: monitoring/Laser/vPhase | Shape: () | Data type: float64
# Dataset: monitoring/Laser/vQuadP | Shape: () | Data type: float64
# Group: processingChain
# Group: processingChain/step-0
# Group: processingChain/step-0/cols
# Dataset: processingChain/step-0/cols/roiDec | Shape: (1,) | Data type: int32
# Dataset: processingChain/step-0/cols/roiEnd | Shape: (1,) | Data type: int32
# Dataset: processingChain/step-0/cols/roiFiberOverlength | Shape: (1,) | Data type: float64
# Dataset: processingChain/step-0/cols/roiRefractiveIndex | Shape: (1,) | Data type: float64
# Dataset: processingChain/step-0/cols/roiStart | Shape: (1,) | Data type: int32
# Dataset: processingChain/step-0/cols/roiStartPosition | Shape: (1,) | Data type: float64
# Dataset: processingChain/step-0/cols/unit | Shape: () | Data type: object
# Group: processingChain/step-0/data
# Dataset: processingChain/step-0/data/unit | Shape: () | Data type: object
# Dataset: processingChain/step-0/modName | Shape: () | Data type: object
# Dataset: processingChain/step-0/objName | Shape: () | Data type: object
# Dataset: processingChain/step-0/plotMode | Shape: () | Data type: object
# Dataset: processingChain/step-0/portName | Shape: () | Data type: object
# Group: processingChain/step-0/time
# Dataset: processingChain/step-0/time/sf | Shape: () | Data type: float64
# Dataset: processingChain/step-0/time/unit | Shape: () | Data type: object
# Group: sweepSpec
# Dataset: sweepSpec/SBW | Shape: () | Data type: float64
# Group: sweepSpec/apod
# Dataset: sweepSpec/apod/duration | Shape: () | Data type: float64
# Dataset: sweepSpec/apod/power | Shape: () | Data type: float64
# Dataset: sweepSpec/apod/shape | Shape: () | Data type: object
# Dataset: sweepSpec/charRate | Shape: () | Data type: float64
# Dataset: sweepSpec/delay_x | Shape: (16,) | Data type: uint32
# Dataset: sweepSpec/delay_y | Shape: (16,) | Data type: uint32
# Dataset: sweepSpec/freqCtr | Shape: () | Data type: float64
# Dataset: sweepSpec/freqOffs | Shape: () | Data type: float64
# Dataset: sweepSpec/gcoeff_x | Shape: (1024, 14) | Data type: uint32
# Dataset: sweepSpec/gcoeff_y | Shape: (1024, 14) | Data type: uint32
# Dataset: sweepSpec/nPeriod | Shape: () | Data type: int64
# Dataset: sweepSpec/nSamples | Shape: () | Data type: int64
# Dataset: sweepSpec/nSweep | Shape: () | Data type: int64
# Dataset: sweepSpec/postSamples | Shape: () | Data type: int64
# Dataset: sweepSpec/preSamples | Shape: () | Data type: int64
# Dataset: sweepSpec/rate | Shape: () | Data type: float64
# Dataset: sweepSpec/reversed | Shape: () | Data type: int32
# Dataset: sweepSpec/scale | Shape: () | Data type: float64
# Group: sweepSpec/swFreqs
# Dataset: sweepSpec/swFreqs/f | Shape: (2,) | Data type: float64
# Dataset: sweepSpec/swFreqs/order | Shape: () | Data type: int32
# Dataset: sweepSpec/swFreqs/t | Shape: (2,) | Data type: float64
# Dataset: sweepSpec/sweepName | Shape: () | Data type: object
# Dataset: sweepSpec/sweepspecVersion | Shape: () | Data type: int32
# Dataset: sweepSpec/uuid | Shape: () | Data type: object
# Group: timing
# Dataset: timing/ppses | Shape: (0,) | Data type: float64
# Dataset: timing/sampleDelayPPS | Shape: () | Data type: float64
# Dataset: timing/sampleSkew | Shape: () | Data type: float64
# Dataset: timing/triggers | Shape: (0,) | Data type: float64
# Group: versions
# Group: versions/Acq
# Dataset: versions/Acq/git ver 1 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 10 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 11 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 12 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 13 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 14 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 15 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 16 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 17 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 18 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 19 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 2 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 20 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 21 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 22 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 23 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 24 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 25 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 3 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 4 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 5 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 6 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 7 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 8 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver 9 | Shape: () | Data type: object
# Dataset: versions/Acq/git ver FW Highest | Shape: () | Data type: object
# Dataset: versions/Acq/git ver dasacq | Shape: () | Data type: object
# Dataset: versions/Acq/hw ver. FPGA | Shape: () | Data type: object
# Dataset: versions/Acq/mac addr | Shape: () | Data type: object
# Dataset: versions/Acq/ser no. FPGA | Shape: () | Data type: object
# Dataset: versions/Acq/svn ver 0 | Shape: () | Data type: object
# Group: versions/Ctrl
# Dataset: versions/Ctrl/serial | Shape: () | Data type: uint32
# Dataset: versions/Ctrl/swRevision | Shape: () | Data type: uint32
# Dataset: versions/Ctrl/swVersion | Shape: () | Data type: uint32
# Group: versions/DasControl
# Dataset: versions/DasControl/swRevision | Shape: () | Data type: object
# Dataset: versions/DasControl/swRevisionCalc | Shape: () | Data type: uint32
# Dataset: versions/DasControl/swVersion | Shape: () | Data type: float64
# Group: versions/Edfa
# Dataset: versions/Edfa/hwRevision | Shape: () | Data type: int32
# Dataset: versions/Edfa/hwVersion | Shape: () | Data type: int32
# Dataset: versions/Edfa/serial | Shape: () | Data type: int32
# Dataset: versions/Edfa/swVersion | Shape: () | Data type: float64
# Group: versions/Gps
# Dataset: versions/Gps/serial | Shape: () | Data type: int32
# Dataset: versions/Gps/version | Shape: () | Data type: float64
# Group: versions/Instr
# Dataset: versions/Instr/serial | Shape: () | Data type: int32
# Group: versions/Laser
# Dataset: versions/Laser/address | Shape: () | Data type: int32
# Dataset: versions/Laser/hwOptions | Shape: () | Data type: int32
# Dataset: versions/Laser/hwVersion | Shape: () | Data type: int32
# Dataset: versions/Laser/pcbVersion | Shape: () | Data type: int32
# Dataset: versions/Laser/serial | Shape: () | Data type: int32
# Dataset: versions/Laser/swVersion | Shape: () | Data type: float64
