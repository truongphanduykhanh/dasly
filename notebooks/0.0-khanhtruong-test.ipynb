# %%
import os

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

from src import dasly, helper

# %%
# file_paths = dasly.Dasly.get_file_paths(
#     folder_path='/mnt/Datastore/usr/kptroung/Svalbard_whale/',
#     # folder_path='/media/kptruong/yellow02/Aastfjordbrua',
#     start='20230901 055954',
#     # end='20230628 113128',
#     duration=11
# )

# %%
das = dasly.Dasly()
das.load_data(
    # folder_path='/media/kptruong/yellow02/Campus_test_20230628/',
    folder_path='/mnt/Datastore/usr/kptroung/Svalbard_whale/test/',
    start='20230628 122057',
    # end='20230628 113128',
    duration=10
)
# Out:
# Welcome to Dasly!
# a
# 2 files,from 122057 to 122107
# b
# /mnt/Datastore/usr/kptroung/dasly/src/dasly.py:236: UserWarning: Data folder does not follow standard format
#             folder/YYYYMMDD/dphi/HHMMSS.hdf5
#   file_paths = Dasly.get_file_paths(

# %%
das.signal
# Out:
# Empty DataFrame
# Columns: [0, 4, 8, 12, 16, 20, 24, 28, 32, 36, 40, 44, 48, 52, 56, 60, 64, 68, 72, 76, 80, 84, 88, 92, 96, 100, 104, 108, 112, 116, 120, 124, 128, 132, 136, 140, 144, 148, 152, 156, 160, 164, 168, 172, 176, 180, 184, 188, 192, 196, 200, 204, 208, 212, 216, 220, 224, 228, 232, 236, 240, 244, 248, 252, 256, 260, 264, 268, 272, 276, 280, 284, 288, 292, 296, 300, 304, 308, 312, 316, 320, 324, 328, 332, 336, 340, 344, 348, 352, 356, 360, 364, 368, 372, 376, 380, 384, 388, 392, 396, ...]
# Index: []
#
# [0 rows x 33748 columns]

# %%
das.heatmap()
# Out:
# Heatmap with vmin -1.39e-05, vmax 1.39e-05
