# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

from dasly import utils

# %%
log = pd.read_excel('../data/logs/vehicle-logs.xlsx')
log
# Out:
#                        Time   Type  Trailer Direction camera  \
# 0   2023-10-05 08:06:55.000    Car      NaN     coming close
# 1   2023-10-05 08:07:39.000  Truck      NaN        going far
# 2   2023-10-05 08:08:02.000    Car      NaN     coming close
# 3   2023-10-05 08:08:12.000    Car      NaN        going far
# 4   2023-10-05 08:08:25.000    Car      NaN     coming close
# ..                      ...    ...      ...              ...
# 351 2023-10-05 11:03:56.070    Car      NaN        going far
# 352 2023-10-05 11:04:22.070    Car      NaN     coming close
# 353 2023-10-05 11:04:53.260    Car      NaN     coming close
# 354 2023-10-05 11:05:20.580    Car      NaN     coming close
# 355 2023-10-05 11:05:52.000    Car      NaN     coming close
#
#                  Direction map Note  YOLO  No signal
# 0    Åstfjordbrua -> Trondheim  NaN   NaN        NaN
# 1    Trondheim -> Åstfjordbrua  NaN   NaN        NaN
# 2    Åstfjordbrua -> Trondheim  NaN   NaN        NaN
# 3    Trondheim -> Åstfjordbrua  NaN   NaN        NaN
# 4    Åstfjordbrua -> Trondheim  NaN   1.0        1.0
# ..                         ...  ...   ...        ...
# 351  Trondheim -> Åstfjordbrua  NaN   NaN        NaN
# 352  Åstfjordbrua -> Trondheim  NaN   NaN        NaN
# 353  Åstfjordbrua -> Trondheim  NaN   NaN        NaN
# 354  Åstfjordbrua -> Trondheim  NaN   NaN        NaN
# 355  Åstfjordbrua -> Trondheim  NaN   NaN        NaN
#
# [356 rows x 8 columns]

# %%
(
    log
    .loc[lambda df: df['No signal'] != 1]
    .groupby('Type')
    .size()
)
# Out:
# Type
# Bus        3
# Car      229
# Moto       3
# Other      1
# Truck     68
# Van       42
# dtype: int64

# %%
(
    log
    .loc[lambda df: df['No signal'] != 1]
    .loc[lambda df: df['Type'].isin(['Car', 'Bus', 'Truck', 'Van'])]
    .assign(Type=lambda df: np.where(df['Type'].isin(['Car', 'Van']), 'Small', 'Large'))
    .groupby('Type')
    .size()
)
# Out:
# Type
# Large     71
# Small    271
# dtype: int64

# %%
(
    log
    .loc[lambda df: df['No signal'] != 1]
    .loc[lambda df: df['Type'].isin(['Car', 'Bus', 'Truck', 'Van'])]
    .assign(Type2=lambda df: np.where(df['Type'].isin(['Car', 'Van']), 'Small', 'Large'))
    .assign(Time2=lambda df: np.where(
        df['Direction camera'] == 'coming close',
        df['Time'] - pd.Timedelta(seconds=30),
        df['Time'] + pd.Timedelta(seconds=30)
    ))
)
# Out:
#                        Time   Type  Trailer Direction camera  \
# 0   2023-10-05 08:06:55.000    Car      NaN     coming close
# 1   2023-10-05 08:07:39.000  Truck      NaN        going far
# 2   2023-10-05 08:08:02.000    Car      NaN     coming close
# 3   2023-10-05 08:08:12.000    Car      NaN        going far
# 5   2023-10-05 08:13:24.000    Car      NaN     coming close
# ..                      ...    ...      ...              ...
# 351 2023-10-05 11:03:56.070    Car      NaN        going far
# 352 2023-10-05 11:04:22.070    Car      NaN     coming close
# 353 2023-10-05 11:04:53.260    Car      NaN     coming close
# 354 2023-10-05 11:05:20.580    Car      NaN     coming close
# 355 2023-10-05 11:05:52.000    Car      NaN     coming close
#
#                  Direction map Note  YOLO  No signal  Type2  \
# 0    Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
# 1    Trondheim -> Åstfjordbrua  NaN   NaN        NaN  Large
# 2    Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
# 3    Trondheim -> Åstfjordbrua  NaN   NaN        NaN  Small
# 5    Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
# ..                         ...  ...   ...        ...    ...
# 351  Trondheim -> Åstfjordbrua  NaN   NaN        NaN  Small
# 352  Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
# 353  Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
# 354  Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
# 355  Åstfjordbrua -> Trondheim  NaN   NaN        NaN  Small
#
#                       Time2
# 0   2023-10-05 08:06:25.000
# 1   2023-10-05 08:08:09.000
# 2   2023-10-05 08:07:32.000
# 3   2023-10-05 08:08:42.000
# 5   2023-10-05 08:12:54.000
# ..                      ...
# 351 2023-10-05 11:04:26.070
# 352 2023-10-05 11:03:52.070
# 353 2023-10-05 11:04:23.260
# 354 2023-10-05 11:04:50.580
# 355 2023-10-05 11:05:22.000
#
# [342 rows x 10 columns]

# %%
time_ends = (
    log
    .loc[lambda df: df['No signal'] != 1]
    .loc[lambda df: df['Type'].isin(['Car', 'Bus', 'Truck', 'Van'])]
    .assign(Type=lambda df: np.where(df['Type'].isin(['Car', 'Van']), 'Small', 'Large'))
    .assign(Time2=lambda df: np.where(
        df['Direction camera'] == 'coming close',
        df['Time'] - pd.Timedelta(seconds=30),
        df['Time'] + pd.Timedelta(seconds=30)
    ))
    .loc[:, ['Time', 'Time2']]
    .to_numpy()
)

time_ends_df = pd.DataFrame(np.sort(time_ends, axis=1), columns=['t1', 't2'])
time_ends_df
# Out:
#                          t1                      t2
# 0   2023-10-05 08:06:25.000 2023-10-05 08:06:55.000
# 1   2023-10-05 08:07:39.000 2023-10-05 08:08:09.000
# 2   2023-10-05 08:07:32.000 2023-10-05 08:08:02.000
# 3   2023-10-05 08:08:12.000 2023-10-05 08:08:42.000
# 4   2023-10-05 08:12:54.000 2023-10-05 08:13:24.000
# ..                      ...                     ...
# 337 2023-10-05 11:03:56.070 2023-10-05 11:04:26.070
# 338 2023-10-05 11:03:52.070 2023-10-05 11:04:22.070
# 339 2023-10-05 11:04:23.260 2023-10-05 11:04:53.260
# 340 2023-10-05 11:04:50.580 2023-10-05 11:05:20.580
# 341 2023-10-05 11:05:22.000 2023-10-05 11:05:52.000
#
# [342 rows x 2 columns]

# %%
vehicle_counts = (
    log
    .loc[lambda df: df['No signal'] != 1]
    .loc[lambda df: df['Type'].isin(['Car', 'Bus', 'Truck', 'Van'])]
    .assign(Type2=lambda df: np.where(df['Type'].isin(['Car', 'Van']), 'Small', 'Large'))
    .assign(Time2=lambda df: np.where(
        df['Direction camera'] == 'coming close',
        df['Time'] - pd.Timedelta(seconds=30),
        df['Time'] + pd.Timedelta(seconds=30)
    ))
    .loc[:, ['Type', 'Type2', 'Direction camera']]
    .reset_index(drop=True)
)
vehicle_counts
# Out:
#       Type  Type2 Direction camera
# 0      Car  Small     coming close
# 1    Truck  Large        going far
# 2      Car  Small     coming close
# 3      Car  Small        going far
# 4      Car  Small     coming close
# ..     ...    ...              ...
# 337    Car  Small        going far
# 338    Car  Small     coming close
# 339    Car  Small     coming close
# 340    Car  Small     coming close
# 341    Car  Small     coming close
#
# [342 rows x 3 columns]

# %%
result = (
    pd.concat([vehicle_counts, time_ends_df], axis=1)
    .assign(s1=lambda df: np.where(df['Direction camera'] == 'coming close', 0, 692))
    .assign(s2=lambda df: np.where(df['Direction camera'] == 'going far', 0, 692))
)
result
# Out:
#       Type  Type2 Direction camera                      t1  \
# 0      Car  Small     coming close 2023-10-05 08:06:25.000
# 1    Truck  Large        going far 2023-10-05 08:07:39.000
# 2      Car  Small     coming close 2023-10-05 08:07:32.000
# 3      Car  Small        going far 2023-10-05 08:08:12.000
# 4      Car  Small     coming close 2023-10-05 08:12:54.000
# ..     ...    ...              ...                     ...
# 337    Car  Small        going far 2023-10-05 11:03:56.070
# 338    Car  Small     coming close 2023-10-05 11:03:52.070
# 339    Car  Small     coming close 2023-10-05 11:04:23.260
# 340    Car  Small     coming close 2023-10-05 11:04:50.580
# 341    Car  Small     coming close 2023-10-05 11:05:22.000
#
#                          t2   s1   s2
# 0   2023-10-05 08:06:55.000    0  692
# 1   2023-10-05 08:08:09.000  692    0
# 2   2023-10-05 08:08:02.000    0  692
# 3   2023-10-05 08:08:42.000  692    0
# 4   2023-10-05 08:13:24.000    0  692
# ..                      ...  ...  ...
# 337 2023-10-05 11:04:26.070  692    0
# 338 2023-10-05 11:04:22.070    0  692
# 339 2023-10-05 11:04:53.260    0  692
# 340 2023-10-05 11:05:20.580    0  692
# 341 2023-10-05 11:05:52.000    0  692
#
# [342 rows x 7 columns]

# %%
result.to_excel('../data/logs/vehicle-log-clean.xlsx', index=False)
