# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
sns.set()

# %%
from scipy import fft

# %%
pi = np.pi

# %%
n = np.arange(0, 100)

a1 = 3
a2 = 1
a3 = 0.2

f1 = 1/25
f2 = 1/9
f3 = 1/4

phi1 = 1/2*pi  # 90 degress
phi2 = 1/6*pi  # 30 degrees
phi3 = 1*pi  # 180 degrees

sig1 = a1*np.sin(2*pi*f1*n + phi1)
sig2 = a2*np.sin(2*pi*f2*n + phi2)
sig3 = a3*np.sin(2*pi*f3*n + phi3)

x = (sig1 + sig2 + sig3)

a_max = np.max([a1, a2, a3])*1.5
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize=(10, 10))
ax1.plot(n, sig1)
ax1.set_ylim(ymin=-a_max, ymax=a_max)
ax2.plot(n, sig2)
ax2.set_ylim(ymin=-a_max, ymax=a_max)
ax3.plot(n, sig3)
ax3.set_ylim(ymin=-a_max, ymax=a_max)
ax4.stem(n, x, 'r')
ax4.set_ylim(ymin=-a_max, ymax=a_max);

# %%
X = fft.fft(x)

# %%
sampling_rate = 20
freq = np.linspace(0, sampling_rate/2, round(len(X)/2) + 1)
normalized_amplitude = abs(X) / len(X) * 2
plt.figure(figsize = (8, 4))
plt.stem(freq, normalized_amplitude[0: len(freq)], 'b', markerfmt=" ", basefmt="-b")
plt.xlabel('Frequency F (Hz)')
plt.ylabel('Normalized Amplitude');

# %% [markdown]
# ___

# %%
n = np.arange(0, 100)

a1 = 3
a2 = 1
a3 = 0.2

f1 = 1/25
f2 = 1/9
f3 = 1/4

phi1 = 1/2*pi  # 90 degress
phi2 = 1/6*pi  # 30 degrees

sig1 = a1*np.sin(2*pi*f1*n + phi1)
sig2 = a2*np.sin(2*pi*f2*n + phi2)
sig3 = a3*np.sin(2*pi*f3*n + phi3)

# x = (sig1 + sig2 + sig3)
x = np.concatenate((sig3[0:25], (sig1 + sig2)[25:75], sig3[75:100]))

a_max = np.max([a1, a2, a3])*1.5
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize=(10, 10))
ax1.plot(n, sig1)
ax1.set_ylim(ymin=-a_max, ymax=a_max)
ax2.plot(n, sig2)
ax2.set_ylim(ymin=-a_max, ymax=a_max)
ax3.plot(n, sig3)
ax3.set_ylim(ymin=-a_max, ymax=a_max)
ax4.stem(n, x, 'r')
ax4.set_ylim(ymin=-a_max, ymax=a_max);

# %%
X = fft.fft(x)
sampling_rate = 20
freq = np.linspace(0, sampling_rate/2, round(len(X)/2) + 1)
normalized_amplitude = abs(X) / len(X) * 2 *2
plt.figure(figsize = (8, 4))
plt.stem(freq, normalized_amplitude[0: len(freq)], 'b', markerfmt=" ", basefmt="-b")
plt.xlabel('Frequency F (Hz)')
plt.ylabel('Normalized Amplitude');

# %%
n = np.arange(0, 100)

a1 = 3
a2 = 1
a3 = 0.2

f1 = 1/25
f2 = 1/9
f3 = 1/4

phi1 = 1/2*pi  # 90 degress
phi2 = 1/6*pi  # 30 degrees

sig1 = a1*np.sin(2*pi*f1*n + phi1)
sig2 = a2*np.sin(2*pi*f2*n + phi2)
sig3 = a3*np.sin(2*pi*f3*n + phi3)

# x = (sig1 + sig2 + sig3)
x = np.concatenate((sig3[0:50], (sig1 + sig2)[50:75], sig3[75:100]))

a_max = np.max([a1, a2, a3])*1.5
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize=(10, 10))
ax1.plot(n, sig1)
ax1.set_ylim(ymin=-a_max, ymax=a_max)
ax2.plot(n, sig2)
ax2.set_ylim(ymin=-a_max, ymax=a_max)
ax3.plot(n, sig3)
ax3.set_ylim(ymin=-a_max, ymax=a_max)
ax4.stem(n, x, 'r')
ax4.set_ylim(ymin=-a_max, ymax=a_max);

# %%
X = fft.fft(x)
sampling_rate = 20
freq = np.linspace(0, sampling_rate/2, round(len(X)/2) + 1)
normalized_amplitude = abs(X) / len(X) * 2 * 4
plt.figure(figsize = (8, 4))
plt.stem(freq, normalized_amplitude[0: len(freq)], 'b', markerfmt=" ", basefmt="-b")
# plt.stem(freq, np.abs(X)[0: len(freq)], 'b', markerfmt=" ", basefmt="-b")
plt.xlabel('Frequency F (Hz)')
plt.ylabel('Normalized Amplitude');

# %%
n = np.arange(0, 100)

a1 = 3
a2 = 1
a3 = 0.2

f1 = 1/25
f2 = 1/9
f3 = 1/4

phi1 = 1/2*pi  # 90 degress
phi2 = 1/6*pi  # 30 degrees

sig1 = a1*np.sin(2*pi*f1*n + phi1)
sig2 = a2*np.sin(2*pi*f2*n + phi2)
sig3 = a3*np.sin(2*pi*f3*n + phi3)

# x = (sig1 + sig2 + sig3)
x = np.concatenate((sig3[0:70], (sig1 + sig2)[70:75], sig3[75:100]))

a_max = np.max([a1, a2, a3])*1.5
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, figsize=(10, 10))
ax1.plot(n, sig1)
ax1.set_ylim(ymin=-a_max, ymax=a_max)
ax2.plot(n, sig2)
ax2.set_ylim(ymin=-a_max, ymax=a_max)
ax3.plot(n, sig3)
ax3.set_ylim(ymin=-a_max, ymax=a_max)
ax4.stem(n, x, 'r')
ax4.set_ylim(ymin=-a_max, ymax=a_max);

# %%
X = fft.fft(x)
sampling_rate = 20
freq = np.linspace(0, sampling_rate/2, round(len(X)/2) + 1)
normalized_amplitude = abs(X) / len(X) * 2 * 4
plt.figure(figsize = (8, 4))
plt.stem(freq, normalized_amplitude[0: len(freq)], 'b', markerfmt=" ", basefmt="-b")
# plt.stem(freq, np.abs(X)[0: len(freq)], 'b', markerfmt=" ", basefmt="-b")
plt.xlabel('Frequency F (Hz)')
plt.ylabel('Normalized Amplitude');
